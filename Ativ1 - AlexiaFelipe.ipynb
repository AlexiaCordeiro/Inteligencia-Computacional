# %% [markdown]
# Alunos: Aléxia Cordeiro Oliveira e Felipe Lacerda Fernandes de Assis

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('iris.csv')
# Verificar as primeiras linhas
print(df.head())
# Separar atributos e classe
X = df.drop(columns=['species']) # substitua 'species' pelo nome correto da coluna da classe
y = df['species']
# Normalização
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Divisão treino/teste
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

k_values = range(1, 31)
accuracies = []

for k in k_values:
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  accuracies.append(acc)

plt.plot(k_values, accuracies, marker='o')
plt.xlabel('Número de Vizinhos (k)')
plt.ylabel('Acurácia')
plt.title('Acurácia em função de k')
plt.grid()
plt.xticks(ticks=range(1, 31, 1))
plt.show()

# %%
metrics = ['euclidean', 'manhattan']
for metric in metrics:
  knn = KNeighborsClassifier(n_neighbors=3, metric=metric)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  print(f"Distância: {metric} | Acurácia: {acc:.4f}")
# Out:
# Distância: euclidean | Acurácia: 1.0000
# Distância: manhattan | Acurácia: 1.0000

# %%
weights_list = ['uniform', 'distance']
for w in weights_list:
  knn = KNeighborsClassifier(n_neighbors=3, metric='euclidean', weights=w)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  print(f"Peso: {w} | Acurácia: {acc:.4f}")
# Out:
# Peso: uniform | Acurácia: 1.0000
# Peso: distance | Acurácia: 1.0000

# %% [markdown]
# SEM NORMALIZAÇÃO

# %%
df = pd.read_csv('iris.csv')
# Verificar as primeiras linhas
print(df.head())
# Separar atributos e classe
X = df.drop(columns=['species']) # substitua 'species' pelo nome correto da coluna da classe
y = df['species']
# Normalização
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
# Divisão treino/teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

k_values = range(1, 31)
accuracies = []

for k in k_values:
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  accuracies.append(acc)

plt.plot(k_values, accuracies, marker='o')
plt.xlabel('Número de Vizinhos (k)')
plt.ylabel('Acurácia')
plt.title('Acurácia em função de k')
plt.grid()
plt.xticks(ticks=range(1, 31, 1))
plt.show()

# %%
weights_list = ['uniform', 'distance']
for w in weights_list:
  knn = KNeighborsClassifier(n_neighbors=1, metric='euclidean', weights=w)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  print(f"Peso: {w} | Acurácia: {acc:.4f}")
# Out:
# Peso: uniform | Acurácia: 1.0000
# Peso: distance | Acurácia: 1.0000

# %%
weights_list = ['uniform', 'distance']
for w in weights_list:
  knn = KNeighborsClassifier(n_neighbors=1, metric='euclidean', weights=w)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  print(f"Peso: {w} | Acurácia: {acc:.4f}")
# Out:
# Peso: uniform | Acurácia: 1.0000
# Peso: distance | Acurácia: 1.0000

# %% [markdown]
# WineQT

# %%
df = pd.read_csv('WineQT.csv')
# Verificar as primeiras linhas
print(df.head())
# Separar atributos e classe
X = df.drop(columns=['quality']) # substitua 'quality' pelo nome correto da coluna da classe
y = df['quality']
# Normalização
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Divisão treino/teste
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

k_values = range(1, 31)
accuracies = []

for k in k_values:
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  accuracies.append(acc)

plt.plot(k_values, accuracies, marker='o')
plt.xlabel('Número de Vizinhos (k)')
plt.ylabel('Acurácia')
plt.title('Acurácia em função de k')
plt.grid()
plt.xticks(ticks=range(1, 31, 1))
plt.show()

# %%
metrics = ['euclidean', 'manhattan']
for metric in metrics:
  knn = KNeighborsClassifier(n_neighbors=17, metric=metric)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  print(f"Distância: {metric} | Acurácia: {acc:.4f}")
# Out:
# Distância: euclidean | Acurácia: 0.6356
# Distância: manhattan | Acurácia: 0.6181

# %%
weights_list = ['uniform', 'distance']
for w in weights_list:
  knn = KNeighborsClassifier(n_neighbors=17, metric='euclidean', weights=w)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  print(f"Peso: {w} | Acurácia: {acc:.4f}")
# Out:
# Peso: uniform | Acurácia: 0.6356
# Peso: distance | Acurácia: 0.6822

# %% [markdown]
# WineQT sem normalização

# %%
df = pd.read_csv('WineQT.csv')
# Verificar as primeiras linhas
print(df.head())
# Separar atributos e classe
X = df.drop(columns=['quality']) # substitua 'quality' pelo nome correto da coluna da classe
y = df['quality']
# Normalização
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
# Divisão treino/teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

k_values = range(1, 31)
accuracies = []

for k in k_values:
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  accuracies.append(acc)

plt.plot(k_values, accuracies, marker='o')
plt.xlabel('Número de Vizinhos (k)')
plt.ylabel('Acurácia')
plt.title('Acurácia em função de k')
plt.grid()
plt.xticks(ticks=range(1, 31, 1))
plt.show()

# %%
metrics = ['euclidean', 'manhattan']
for metric in metrics:
  knn = KNeighborsClassifier(n_neighbors=1 , metric=metric)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  print(f"Distância: {metric} | Acurácia: {acc:.4f}")
# Out:
# Distância: euclidean | Acurácia: 0.5306
# Distância: manhattan | Acurácia: 0.5394

# %%
weights_list = ['uniform', 'distance']
for w in weights_list:
  knn = KNeighborsClassifier(n_neighbors=1, metric='euclidean', weights=w)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  print(f"Peso: {w} | Acurácia: {acc:.4f}")
# Out:
# Peso: uniform | Acurácia: 0.5306
# Peso: distance | Acurácia: 0.5306

# %% [markdown]
# EVASÃO

# %%
df = pd.read_csv('evasao.csv')
# Verificar as primeiras linhas
print(df.head())
# Separar atributos e classe
X = df.drop(columns=['ESCOLA_FUNDAMENTAL_Escola Municipal Governador Carlos Lacerda']) # substitua 'quality' pelo nome correto da coluna da classe
y = df['ESCOLA_FUNDAMENTAL_Escola Municipal Governador Carlos Lacerda']
# Normalização
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Divisão treino/teste
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
# Out:
#    Cidade_Ouro Preto/MG  \
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
#
#    ESCOLA_FUNDAMENTAL_Instituto Educacao Manoel Pinheiro  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    ESCOLA_FUNDAMENTAL_E. M. Dom Orione  \
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
#
#    ESCOLA_FUNDAMENTAL_E. M. Pres. Tancredo Neves  N_FILHOS  \
# 0                                              0       0.0
# 1                                              1       0.0
# 2                                              0       0.0
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

k_values = range(1, 31)
accuracies = []

for k in k_values:
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  accuracies.append(acc)

plt.plot(k_values, accuracies, marker='o')
plt.xlabel('Número de Vizinhos (k)')
plt.ylabel('Acurácia')
plt.title('Acurácia em função de k')
plt.grid()
plt.xticks(ticks=range(1, 31, 1))
plt.show()

# %%
metrics = ['euclidean', 'manhattan']
for metric in metrics:
  knn = KNeighborsClassifier(n_neighbors=2, metric=metric)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  print(f"Distância: {metric} | Acurácia: {acc:.4f}")
# Out:
# Distância: euclidean | Acurácia: 0.9854
# Distância: manhattan | Acurácia: 0.9805

# %%
weights_list = ['uniform', 'distance']
for w in weights_list:
  knn = KNeighborsClassifier(n_neighbors=2, metric='euclidean', weights=w)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  print(f"Peso: {w} | Acurácia: {acc:.4f}")
# Out:
# Peso: uniform | Acurácia: 0.9854
# Peso: distance | Acurácia: 0.9805

# %% [markdown]
# evasao sem normalização

# %%
df = pd.read_csv('evasao.csv')
# Verificar as primeiras linhas
print(df.head())
# Separar atributos e classe
X = df.drop(columns=['ESCOLA_FUNDAMENTAL_Escola Municipal Governador Carlos Lacerda']) # substitua 'quality' pelo nome correto da coluna da classe
y = df['ESCOLA_FUNDAMENTAL_Escola Municipal Governador Carlos Lacerda']
# Normalização
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
# Divisão treino/teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
#    Cidade_Ouro Preto/MG  \
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
#
#    ESCOLA_FUNDAMENTAL_Instituto Educacao Manoel Pinheiro  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    ESCOLA_FUNDAMENTAL_E. M. Dom Orione  \
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
#
#    ESCOLA_FUNDAMENTAL_E. M. Pres. Tancredo Neves  N_FILHOS  \
# 0                                              0       0.0
# 1                                              1       0.0
# 2                                              0       0.0
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

k_values = range(1, 31)
accuracies = []

for k in k_values:
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  accuracies.append(acc)

plt.plot(k_values, accuracies, marker='o')
plt.xlabel('Número de Vizinhos (k)')
plt.ylabel('Acurácia')
plt.title('Acurácia em função de k')
plt.grid()
plt.xticks(ticks=range(1, 31, 1))
plt.show()

# %%
metrics = ['euclidean', 'manhattan']
for metric in metrics:
  knn = KNeighborsClassifier(n_neighbors=13, metric=metric)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  print(f"Distância: {metric} | Acurácia: {acc:.4f}")
# Out:
# Distância: euclidean | Acurácia: 0.9902
# Distância: manhattan | Acurácia: 0.9902

# %%
weights_list = ['uniform', 'distance']
for w in weights_list:
  knn = KNeighborsClassifier(n_neighbors=13, metric='euclidean', weights=w)
  knn.fit(X_train, y_train)
  y_pred = knn.predict(X_test)
  acc = accuracy_score(y_test, y_pred)
  print(f"Peso: {w} | Acurácia: {acc:.4f}")
# Out:
# Peso: uniform | Acurácia: 0.9902
# Peso: distance | Acurácia: 0.9854

# %% [markdown]
# # Resumo
#
# ## 5.2.1. Discussão sobre qual configuração teve melhor desempenho e por que para cada conjunto de dados
# A configuração para o iris.csv sem normalizção teve o melhor desempenho. Pois possui uma acurácia de 1 para todos os casos
#
# ## 5.2.2.Observações sobre a influência da normalização
# A normalização teve um impacto positivo claro no desempenho do KNN para o dataset WineQT. Para os datasets Iris e Evasão, o impacto foi menos pronunciado ou até ligeiramente negativo em alguns casos específicos, mas as acurácias já eram muito altas, sugerindo que a escala dos atributos pode não ser o fator mais limitante para o desempenho nesses casos.
